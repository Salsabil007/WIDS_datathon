# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# !ls "/content/drive/My Drive"
# Out:
#  Breakthrough
# 'Colab Notebooks'
#  COMPSCI_765_artifact.gdoc
#  COMPSCI_765_project
# 'Copy of 22s_lis501_week04_solution.ipynb'
# 'Copy of GOAL SETTING.gdoc'
# 'Copy of L&S TA Training Participant Guide - Fall 2022.gdoc'
#  CS_539
#  datathon.gdoc
#  FDA_approval_new_outline.gdoc
#  FDA_approval_supplementary.gdoc
#  FDA_approval_thing_to_do.gdoc
#  How_to_use.gdoc
#  JIF
# 'MD1 correction.gdoc'
#  Methodology.docx
#  performance
#  PHD
#  PHD_save
# 'project noble'
#  PXL_20221201_234739190.jpg
# 'Pytorch toolbox.gdoc'
#  Reading_winter_2022.gdoc
#  sample-paper_CS765.docx
# 'Untitled document.gdoc'
#  week04
#  workshop.gdoc

# %%
data = pd.read_csv("/content/drive/My Drive/wids_datathon_2023/test_data.csv")
